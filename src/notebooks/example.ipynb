# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sbm.sbm_simulator import GenerateStochasticBlockModelWithFeatures
import graph_tool.all as gt
# Out:
# /usr/lib/python3/dist-packages/graph_tool/draw/cairo_draw.py:1501: RuntimeWarning: Error importing Gtk module: No module named 'gi'; GTK+ drawing will not work.
#   warnings.warn(msg, RuntimeWarning)

# %%
sampled_graph = GenerateStochasticBlockModelWithFeatures(
            num_vertices = 10,
            num_edges = 100,
            pi = np.array([0.25, 0.25, 0.25, 0.25]),
            prop_mat = np.ones((4, 4)) + 9.0 * np.diag([1,1,1,1]),
            feature_center_distance = 2.0,
            feature_dim = 16,
            edge_center_distance = 2.0,
            edge_feature_dim = 4)

# %%
gt.graph_draw(sampled_graph.graph)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f84fd5bdb70, at 0x7f84fd5bdcf8>
